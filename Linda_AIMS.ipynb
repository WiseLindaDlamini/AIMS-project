# %%
# !pip install stim~=1.12
# !pip install numpy
# !pip install scipy
# Out:
# Collecting stim~=1.12
#   Downloading stim-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stim~=1.12) (1.25.2)
# Installing collected packages: stim
# Successfully installed stim-1.13.0
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.25.2)

# %%
# !pip install pymatching~=2.0
# Out:
# Collecting pymatching~=2.0
#   Downloading PyMatching-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (613 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pymatching~=2.0) (1.11.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pymatching~=2.0) (1.25.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pymatching~=2.0) (3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pymatching~=2.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pymatching~=2.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pymatching~=2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pymatching~=2.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pymatching~=2.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pymatching~=2.0) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pymatching~=2.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pymatching~=2.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pymatching~=2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pymatching~=2.0) (1.16.0)
# Installing collected packages: pymatching
# Successfully installed pymatching-2.2.0

# %%
# !pip install sinter~=1.12
# Out:
# Collecting sinter~=1.12
#   Downloading sinter-1.13.0.tar.gz (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib~=3.5 in /usr/local/lib/python3.10/dist-packages (from sinter~=1.12) (3.7.1)
# Requirement already satisfied: numpy~=1.22 in /usr/local/lib/python3.10/dist-packages (from sinter~=1.12) (1.25.2)
# Requirement already satisfied: stim~=1.9 in /usr/local/lib/python3.10/dist-packages (from sinter~=1.12) (1.13.0)
# Requirement already satisfied: scipy~=1.9 in /usr/local/lib/python3.10/dist-packages (from sinter~=1.12) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5->sinter~=1.12) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5->sinter~=1.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5->sinter~=1.12) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5->sinter~=1.12) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5->sinter~=1.12) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5->sinter~=1.12) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5->sinter~=1.12) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5->sinter~=1.12) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.5->sinter~=1.12) (1.16.0)
# Building wheels for collected packages: sinter
#   Building wheel for sinter (setup.py) ... done
#   Created wheel for sinter: filename=sinter-1.13.0-py3-none-any.whl size=174168 sha256=cf689da74dc5769c97e63833450bd7b9f9af1e002920132ebd0157dd370a0e16
#   Stored in directory: /root/.cache/pip/wheels/3a/36/ab/8370a985fec35408e65fe5e7864b0d570be74957dd063a4e75
# Successfully built sinter
# Installing collected packages: sinter
# Successfully installed sinter-1.13.0

# %%
import matplotlib.pyplot as plt
import pymatching
import sinter
from typing import List
import scipy.stats
import numpy as np
import stim
print(stim.__version__)
# Out:
# 1.13.0

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=0,
            before_measure_flip_probability=0,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,2.05e-2)
y = [0.0149 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-6, 5e-1)
ax.set_xlim(0.008, 0.019)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=0,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=0,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9]
    for noise in [0.14, 0.17, 0.19, 0.21, 0.22, 0.24, 0.27, 0.31]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=1_000_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,6e-2)
y = [0.222 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-6, 5e-1)
ax.set_xlim(0.14, 0.24)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=0,
            after_reset_flip_probability=0,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9]
    for noise in [ 0.1, 0.11, 0.12,0.14,0.19, 0.21, 0.23, 0.25, 0.29, 0.33]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=1_000_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,6e-2)
y = [0.22 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-6, 5e-1)
ax.set_xlim(0.1, 0.25)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=0,
            after_reset_flip_probability=0,
            before_measure_flip_probability=0,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9]
    for noise in [0.08, 0.09, 0.1, 0.11, 0.12,0.14,0.19]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=1_000_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,1e-1)
y = [0.12 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-6, 5e-1)
ax.set_xlim(0.08, 0.19)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=0,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,2.5e-2)
y = [0.0129 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-5, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=0,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,2.5e-2)
y = [0.0132 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-5, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=0,
            before_measure_flip_probability=0,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,2.5e-2)
y = [0.0125 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-5, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,2.5e-2)
y = [0.012 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-5, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=0,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012, 0.014]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,2.5e-2)
y = [0.0113 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-5, 5e-2)
ax.set_xlim(0.008, 0.012)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=0,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012, 0.014]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,2.5e-2)
y = [0.0113 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-5, 5e-2)
ax.set_xlim(0.008, 0.012)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_x",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,2.2e-2)
y = [0.0096 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-4, 5e-1)
ax.set_xlim(0.008, 0.012)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=0,
            before_measure_flip_probability=0,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,5e-2)
y = [0.0145 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1,
    # line_fits = True
)
ax.plot(y,x,'--')
ax.set_ylim(5e-8, 5e-2)
ax.set_xlim(0.008, 0.019)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.grid()
ax.legend()
fig.set_dpi(120)

# %%
sinter.collect

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,5e-2)
y = [0.0145 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1
)
ax.plot(y,x,'--')
ax.set_ylim(5e-4, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.legend()
ax.grid()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=0,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,5e-2)
y = [0.0145 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1
)
ax.plot(y,x,'--')
ax.set_ylim(5e-4, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.legend()
ax.grid()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012,0.014,0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,5e-2)
y = [0.0145 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1
)
ax.plot(y,x,'--')
ax.set_ylim(5e-4, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.legend()
ax.grid()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=0,
            before_measure_flip_probability=0,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012, 0.014, 0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,5e-2)
y = [0.0145 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1
)
ax.plot(y,x,'--')
ax.set_ylim(5e-4, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.legend()
ax.grid()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=0,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012, 0.014, 0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,5e-2)
y = [0.0145 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1
)
ax.plot(y,x,'--')
ax.set_ylim(5e-9, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.legend()
ax.grid()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=0,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012, 0.014, 0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,5e-2)
y = [0.0145 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1
)
ax.plot(y,x,'--')
ax.set_ylim(5e-4, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.legend()
ax.grid()
fig.set_dpi(120)

# %%
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=0,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=0,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9, 11]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012, 0.014, 0.019]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=100_000,
    max_errors=5_000,
    print_progress=False,
)

# %%
x = np.linspace(5e-8,5e-2)
y = [0.0145 for i in x]
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
    highlight_max_likelihood_factor =1
)
ax.plot(y,x,'--')
ax.set_ylim(5e-4, 5e-2)
ax.set_xlim(0.008, 0.014)
ax.semilogy()
ax.set_xlabel("Physical error rate(p)")
ax.set_ylabel("Logical error rate per Round")
ax.legend()
ax.grid()
fig.set_dpi(120)
